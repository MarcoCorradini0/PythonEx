# %% [markdown]
# # Test Notebook – Verifica ambiente Jupyter
# Questo notebook serve a verificare che Jupyter funzioni correttamente dentro Visual Studio Code e che il kernel selezionato sia quello dell'ambiente virtuale `.venv`.

# %%
import sys, platform
print('Percorso interprete Python:', sys.executable)
print('Versione Python:', platform.python_version())
# Out:
# Percorso interprete Python: /home/marco/projects/PythonEx/src/Modulo 2/venv_modulo2/bin/python
# Versione Python: 3.14.2

# %% [markdown]
# ## Test pacchetti
# Questa cella verifica che i pacchetti installati nel tuo ambiente virtuale siano visibili al notebook.

# %%
try:
    import requests
    print('Modulo requests disponibile, versione:', requests.__version__)
except ImportError:
    print('Modulo requests NON trovato. Installa con: pip install requests')
# Out:
# Modulo requests disponibile, versione: 2.32.5

# %% [markdown]
# ## Test grafico (matplotlib)
# Se questa cella produce un grafico, l'ambiente è configurato correttamente.

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [10,20,25,30])
plt.title('Test Matplotlib')
plt.show()
